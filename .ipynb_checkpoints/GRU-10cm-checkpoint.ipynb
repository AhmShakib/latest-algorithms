# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K



df = pd.read_csv("FourRegionData.csv")
df.head(10)
# Out:
# WARNING:tensorflow:From C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#    Region  Year  Month  SoilTemperature-10  SoilTemperature-30  \
# 0       2  2001      1               17.40               18.81
# 1       2  2001      2               19.88               19.98
# 2       2  2001      3               24.08               23.32
# 3       2  2001      4               27.62               27.02
# 4       2  2001      5               28.54               28.29
# 5       2  2001      6               30.11               29.82
# 6       2  2001      7               30.74               30.53
# 7       2  2001      8               30.99               30.99
# 8       2  2001      9               29.83               29.89
# 9       2  2001     10               28.00               28.29
#
#    SoilTemperature-50  Rainfall  Temperature  Min Temperature  \
# 0               19.43         0        18.38            13.04
# 1               20.36         1        22.61            16.90
# 2               23.17        33        26.62            20.73
# 3               26.77        46        29.06            24.71
# 4               28.21       402        27.69            24.18
# 5               29.64       386        28.03            25.55
# 6               30.64       202        28.83            25.92
# 7               30.86       205        29.46            25.23
# 8               29.95       209        28.71            24.34
# 9               28.50       177        27.63            22.83
#
#    Max Temperature  Humidity  Sunshine  Wind Speed  Surface Pressure  \
# 0            25.44     62.68      7.94        2.17         101268.29
# 1            28.56     61.71      7.19        1.98         101039.08
# 2            31.84     55.48      8.75        2.10         100882.56
# 3            32.06     65.63      8.55        2.70         100655.40
# 4            32.09     77.39      6.10        2.37         100234.63
# 5            31.75     83.17      3.51        3.64          99934.18
# 6            31.60     80.26      4.55        3.87          99991.05
# 7            31.50     82.19      5.15        3.01         100129.68
# 8            32.42     82.53      4.65        2.14         100499.17
# 9            31.44     80.45      5.60        1.59         100864.38
#
#    Solar Radiation
# 0           199.25
# 1           210.73
# 2           251.75
# 3           257.46
# 4           172.32
# 5           140.45
# 6           169.40
# 7           181.66
# 8           170.22
# 9           167.89

# %%
# Feature and target selection
features = df[['Month', 'Temperature', 'Min Temperature',
               'Max Temperature', 'Surface Pressure']]
target = df['SoilTemperature-30']

# Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

target_scaler = MinMaxScaler()
y_scaled = target_scaler.fit_transform(target.values.reshape(-1, 1))

# Sliding window function
def create_sliding_window(X, y, window_size):
    Xs, ys = [], []
    for i in range(len(X) - window_size):
        Xs.append(X[i:i+window_size])
        ys.append(y[i+window_size])
    return np.array(Xs), np.array(ys)

# Loop over window sizes
for WINDOW in [3, 6, 9, 12]:
    print(f"\n======================")
    print(f"🔁 Training with WINDOW SIZE: {WINDOW}")
    print(f"======================")

    X_seq, y_seq = create_sliding_window(X_scaled, y_scaled, WINDOW)

    total_samples = len(X_seq)
    train_end = int(0.7 * total_samples)
    val_end = int(0.85 * total_samples)

    X_train, y_train = X_seq[:train_end], y_seq[:train_end]
    X_val, y_val = X_seq[train_end:val_end], y_seq[train_end:val_end]
    X_test, y_test = X_seq[val_end:], y_seq[val_end:]

    # Define GRU model
    model = Sequential([
        GRU(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        GRU(32, return_sequences=True),
        GRU(32, return_sequences=False),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

    # Callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    checkpoint = ModelCheckpoint(f'best_model_window_{WINDOW}.h5', monitor='val_loss', save_best_only=True, mode='min')
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

    # Train
    history = model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, checkpoint, lr_scheduler]
    )
    

    # Evaluate model
    y_true = y_test_rescaled.flatten()
    y_pred = predictions_rescaled.flatten()
    y_mean = np.mean(y_true)
    loss, mae = model.evaluate(X_test, y_test)
    print(f'WINDOW SIZE={WINDOW}')
    print(f"✅ Test Loss (MSE): {loss:.4f}")
    print(f"✅ Test MAE:       {mae:.4f}")

    # Predictions
    predictions = model.predict(X_test)

    # Rescale predictions and actuals
    predictions_rescaled = target_scaler.inverse_transform(predictions)
    y_test_rescaled = target_scaler.inverse_transform(y_test.reshape(-1, 1))

    # Show comparison
    comparison = pd.DataFrame({
        'Predicted': predictions_rescaled.flatten(),
        'Actual': y_test_rescaled.flatten()
    })

    print(comparison[:10])
# Out:
# ======================
# 🔁 Training with WINDOW SIZE: 3
# ======================
# WARNING:tensorflow:From C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\layers\rnn\gru.py:144: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 24/24 [==============================] - 8s 63ms/step - loss: 0.1510 - mae: 0.3108 - val_loss: 0.0364 - val_mae: 0.1398 - lr: 0.0010
# Epoch 2/50
# 17/24 [====================>.........] - ETA: 0s - loss: 0.0300 - mae: 0.1324
# C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0299 - mae: 0.1316 - val_loss: 0.0129 - val_mae: 0.0906 - lr: 0.0010
# Epoch 3/50
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0226 - mae: 0.1150 - val_loss: 0.0093 - val_mae: 0.0737 - lr: 0.0010
# Epoch 4/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0219 - mae: 0.1124 - val_loss: 0.0157 - val_mae: 0.1074 - lr: 0.0010
# Epoch 5/50
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0206 - mae: 0.1072 - val_loss: 0.0084 - val_mae: 0.0725 - lr: 0.0010
# Epoch 6/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0183 - mae: 0.1035 - val_loss: 0.0117 - val_mae: 0.0897 - lr: 0.0010
# Epoch 7/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0165 - mae: 0.0957 - val_loss: 0.0090 - val_mae: 0.0755 - lr: 0.0010
# Epoch 8/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0181 - mae: 0.0987 - val_loss: 0.0114 - val_mae: 0.0882 - lr: 0.0010
# Epoch 9/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0164 - mae: 0.0966 - val_loss: 0.0118 - val_mae: 0.0892 - lr: 0.0010
# Epoch 10/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0155 - mae: 0.0946 - val_loss: 0.0117 - val_mae: 0.0857 - lr: 0.0010
# Epoch 11/50
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0143 - mae: 0.0897 - val_loss: 0.0099 - val_mae: 0.0792 - lr: 2.0000e-04
# Epoch 12/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0153 - mae: 0.0921 - val_loss: 0.0094 - val_mae: 0.0783 - lr: 2.0000e-04
# Epoch 13/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0148 - mae: 0.0905 - val_loss: 0.0098 - val_mae: 0.0806 - lr: 2.0000e-04
# Epoch 14/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0149 - mae: 0.0905 - val_loss: 0.0093 - val_mae: 0.0780 - lr: 2.0000e-04
# Epoch 15/50
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0137 - mae: 0.0868 - val_loss: 0.0098 - val_mae: 0.0810 - lr: 2.0000e-04
# 5/5 [==============================] - 0s 4ms/step - loss: 0.
50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0125 - mae: 0.0847 - val_loss: 0.0064 - val_mae: 0.0609 - lr: 0.0010
# Epoch 10/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0117 - mae: 0.0799 - val_loss: 0.0077 - val_mae: 0.0669 - lr: 0.0010
# Epoch 11/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0126 - mae: 0.0843 - val_loss: 0.0063 - val_mae: 0.0609 - lr: 0.0010
# Epoch 12/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0110 - mae: 0.0769 - val_loss: 0.0063 - val_mae: 0.0617 - lr: 0.0010
# Epoch 13/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0106 - mae: 0.0774 - val_loss: 0.0063 - val_mae: 0.0604 - lr: 0.0010
# Epoch 14/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0115 - mae: 0.0785 - val_loss: 0.0074 - val_mae: 0.0673 - lr: 0.0010
# Epoch 15/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0105 - mae: 0.0744 - val_loss: 0.0066 - val_mae: 0.0641 - lr: 2.0000e-04
# Epoch 16/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0102 - mae: 0.0740 - val_loss: 0.0061 - val_mae: 0.0610 - lr: 2.0000e-04
# Epoch 17/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0111 - mae: 0.0763 - val_loss: 0.0066 - val_mae: 0.0639 - lr: 2.0000e-04
# Epoch 18/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0109 - mae: 0.0756 - val_loss: 0.0061 - val_mae: 0.0609 - lr: 2.0000e-04
# Epoch 19/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0110 - mae: 0.0781 - val_loss: 0.0060 - val_mae: 0.0602 - lr: 2.0000e-04
# Epoch 20/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0096 - mae: 0.0739 - val_loss: 0.0078 - val_mae: 0.0703 - lr: 2.0000e-04
# Epoch 21/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0108 - mae: 0.0753 - val_loss: 0.0064 - val_mae: 0.0620 - lr: 2.0000e-04
# Epoch 22/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0112 - mae: 0.0767 - val_loss: 0.0066 - val_mae: 0.0638 - lr: 4.0000e-05
# Epoch 23/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0101 - mae: 0.0745 - val_loss: 0.0064 - val_mae: 0.0625 - lr: 4.0000e-05
# Epoch 24/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0094 - mae: 0.0707 - val_loss: 0.0066 - val_mae: 0.0636 - lr: 4.0000e-05
# Epoch 25/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0104 - mae: 0.0755 - val_loss: 0.0064 - val_mae: 0.0625 - lr: 4.0000e-05
# Epoch 26/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0104 - mae: 0.0743 - val_loss: 0.0065 - val_mae: 0.0635 - lr: 4.0000e-05
# Epoch 27/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0104 - mae: 0.0750 - val_loss: 0.0065 - val_mae: 0.0636 - lr: 8.0000e-06
# Epoch 28/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0101 - mae: 0.0724 - val_loss: 0.0065 - val_mae: 0.0632 - lr: 8.0000e-06
# Epoch 29/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0097 - mae: 0.0729 - val_loss: 0.0065 - val_mae: 0.0633 - lr: 8.0000e-06
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0044 - mae: 0.0496
# WINDOW SIZE=12
# ✅ Test Loss (MSE): 0.0044
# ✅ Test MAE:       0.0496
# 5/5 [==============================] - 1s 6ms/step
#    Predicted  Actual
# 0  21.780361   21.00
# 1  19.259880   19.75
# 2  21.595840   23.29
# 3  26.529163   28.24
# 4  30.006975   30.61
# 5  31.499783   30.43
# 6  31.655373   30.42
# 7  31.653944   30.93
# 8  31.036453   27.43
# 9  29.990416   29.86

# %%
from sklearn.metrics import r2_score

# Feature and target selection
features = df[['Month', 'Temperature', 'Min Temperature',
               'Max Temperature', 'Surface Pressure']]
target = df['SoilTemperature-30']

# Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

target_scaler = MinMaxScaler()
y_scaled = target_scaler.fit_transform(target.values.reshape(-1, 1))

# Sliding window function
def create_sliding_window(X, y, window_size):
    Xs, ys = [], []
    for i in range(len(X) - window_size):
        Xs.append(X[i:i+window_size])
        ys.append(y[i+window_size])
    return np.array(Xs), np.array(ys)

# Loop over window sizes
for WINDOW in [3, 6, 9, 12]:
    print(f"\n======================")
    print(f"🔁 Training with WINDOW SIZE: {WINDOW}")
    print(f"======================")

    X_seq, y_seq = create_sliding_window(X_scaled, y_scaled, WINDOW)

    total_samples = len(X_seq)
    train_end = int(0.7 * total_samples)
    val_end = int(0.85 * total_samples)

    X_train, y_train = X_seq[:train_end], y_seq[:train_end]
    X_val, y_val = X_seq[train_end:val_end], y_seq[train_end:val_end]
    X_test, y_test = X_seq[val_end:], y_seq[val_end:]

    # Define GRU model
    model = Sequential([
        GRU(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        GRU(32, return_sequences=True),
        GRU(32, return_sequences=False),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

    # Callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    checkpoint = ModelCheckpoint(f'best_model_window_{WINDOW}.h5', monitor='val_loss', save_best_only=True, mode='min')
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

    # Train
    history = model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, checkpoint, lr_scheduler]
    )

    # Evaluate model
    loss, mae = model.evaluate(X_test, y_test)
    print(f'WINDOW SIZE={WINDOW}')
    print(f"✅ Test Loss (MSE): {loss:.4f}")
    print(f"✅ Test MAE:       {mae:.4f}")

    # Predictions
    predictions = model.predict(X_test)

    # Rescale predictions and actuals
    predictions_rescaled = target_scaler.inverse_transform(predictions)
    y_test_rescaled = target_scaler.inverse_transform(y_test.reshape(-1, 1))
    # === 📊 Extra Evaluation Metrics ===
    y_true = y_test_rescaled.flatten()
    y_pred = predictions_rescaled.flatten()
    y_mean = np.mean(y_true)

    # MAPE
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    # R²
    r2 = r2_score(y_true, y_pred)

    # sMAPE
    smape = 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

    # NSE
    nse = 1 - np.sum((y_true - y_pred) ** 2) / np.sum((y_true - y_mean) ** 2)

    # Willmott's d-index
    d_index = 1 - (np.sum((y_true - y_pred) ** 2) /
                   np.sum((np.abs(y_pred - y_mean) + np.abs(y_true - y_mean)) ** 2))

    # ✅ Print all metrics
    print(f"✅RMSE:       {np.sqrt(loss):.2f}")
    print(f"✅ MAPE:     {mape:.2f}%")
    print(f"✅ R²:       {r2:.4f}")
    print(f"✅ sMAPE:    {smape:.2f}%")
    print(f"✅ NSE:      {nse:.4f}")
    print(f"✅ d-index:  {d_index:.4f}")
    
    comparison = pd.DataFrame({
        'Predicted': predictions_rescaled.flatten(),
        'Actual': y_test_rescaled.flatten()
    })

    print(comparison[:10])
# Out:
# ======================
# 🔁 Training with WINDOW SIZE: 3
# ======================
# Epoch 1/50
# 24/24 [==============================] - 7s 61ms/step - loss: 0.1227 - mae: 0.2713 - val_loss: 0.0146 - val_mae: 0.0924 - lr: 0.0010
# Epoch 2/50
# 10/24 [===========>..................] - ETA: 0s - loss: 0.0280 - mae: 0.1254
# C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 24/24 [==============================] - 0s 12ms/step - loss: 0.
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0053 - mae: 0.0539
# WINDOW SIZE=3
# ✅ Test Loss (MSE): 0.0053
# ✅ Test MAE:       0.0539
# 5/5 [==============================] - 1s 6ms/step
# ✅RMSE:       0.07
# ✅ MAPE:     3.49%
# ✅ R²:       0.9005
# ✅ sMAPE:    3.50%
# ✅ NSE:      0.9005
# ✅ d-index:  0.9763
#    Predicted  Actual
# 0  26.003141   25.35
# 1  22.153662   21.00
# 2  19.065424   19.75
# 3  21.584728   23.29
# 4  26.116781   28.24
# 5  30.250797   30.61
# 6  31.367352   30.43
# 7  31.963058   30.42
# 8  31.687178   30.93
# 9  31.037445   27.43
#
# ======================
# 🔁 Training with WINDOW SIZE: 6
# ======================
# Epoch 1/50
# 23/23 [==============================] - 7s 67ms/step - loss: 0.1013 - mae: 0.2446 - val_loss: 0.0206 - val_mae: 0.1221 - lr: 0.0010
# Epoch 2/50
#  7/23 [========>.....................] - ETA: 0s - loss: 0.0360 - mae: 0.1459
# C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0283 - mae: 0.1270 - val_loss: 0.0110 - val_mae: 0.0794 - lr: 0.0010
# Epoch 3/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0200 - mae: 0.1086 - val_loss: 0.0107 - val_mae: 0.0809 - lr: 0.0010
# Epoch 4/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0172 - mae: 0.0978 - val_loss: 0.0078 - val_mae: 0.0677 - lr: 0.0010
# Epoch 5/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0170 - mae: 0.0963 - val_loss: 0.0083 - val_mae: 0.0706 - lr: 0.0010
# Epoch 6/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0146 - mae: 0.0915 - val_loss: 0.0071 - val_mae: 0.0664 - lr: 0.0010
# Epoch 7/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0152 - mae: 0.0939 - val_loss: 0.0088 - val_mae: 0.0740 - lr: 0.0010
# Epoch 8/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0131 - mae: 0.0858 - val_loss: 0.0079 - val_mae: 0.0690 - lr: 0.0010
# Epoch 9/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0147 - mae: 0.0911 - val_loss: 0.0075 - val_mae: 0.0673 - lr: 0.0010
# Epoch 10/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0123 - mae: 0.0846 - val_loss: 0.0074 - val_mae: 0.0677 - lr: 0.0010
# Epoch 11/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0127 - mae: 0.0838 - val_loss: 0.0083 - val_mae: 0.0715 - lr: 0.0010
# Epoch 12/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0123 - mae: 0.0835 - val_loss: 0.0070 - val_mae: 0.0647 - lr: 2.0000e-04
# Epoch 13/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0126 - mae: 0.0838 - val_loss: 0.0081 - val_mae: 0.0707 - lr: 2.0000e-04
# Epoch 14/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0130 - mae: 0.0828 - val_loss: 0.0073 - val_mae: 0.0670 - lr: 2.0000e-04
# Epoch 15/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0128 - mae: 0.0843 - val_loss: 0.0078 - val_mae: 0.0694 - lr: 2.0000e-04
# Epoch 16/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0117 - mae: 0.0809 - val_loss: 0.0066 - val_mae: 0.0628 - lr: 2.0000e-04
# Epoch 17/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0125 - mae: 0.0823 - val_loss: 0.0082 - val_mae: 0.0712 - lr: 2.0000e-04
# Epoch 18/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0120 - mae: 0.0808 - val_loss: 0.0075 - val_mae: 0.0681 - lr: 2.0000e-04
# Epoch 19/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0113 - mae: 0.0782 - val_loss: 0.0089 - val_mae: 0.0746 - lr: 2.0000e-04
# Epoch 20/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0127 - mae: 0.0842 - val_loss: 0.0079 - val_mae: 0.0697 - lr: 2.0000e-04
# Epoch 21/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0108 - mae: 0.0781 - val_loss: 0.0074 - val_mae: 0.0675 - lr: 2.0000e-04
# Epoch 22/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0118 - mae: 0.0788 - val_loss: 0.0074 - val_mae: 0.0675 - lr: 4.0000e-05
# Epoch 23/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0112 - mae: 0.0792 - val_loss: 0.0077 - val_mae: 0.0687 - lr: 4.0000e-05
# Epoch 24/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0112 - mae: 0.0786 - val_loss: 0.0077 - val_mae: 0.0690 - lr: 4.0000e-05
# Epoch 25/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0110 - mae: 0.0792 - val_loss: 0.0072 - val_mae: 0.0665 - lr: 4.0000e-05
# Epoch 26/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0121 - mae: 0.0810 - val_loss: 0.0069 - val_mae: 0.0648 - lr: 4.0000e-05
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0043 - mae: 0.0485
# WINDOW SIZE=6
# ✅ Test Loss (MSE): 0.0043
# ✅ Test MAE:       0.0485
# 5/5 [==============================] - 1s 4ms/step
# ✅RMSE:       0.07
# ✅ MAPE:     3.15%
# ✅ R²:       0.9180
# ✅ sMAPE:    3.16%
# ✅ NSE:      0.9180
# ✅ d-index:  0.9804
#    Predicted  Actual
# 0  25.885216   25.35
# 1  22.130064   21.00
# 2  18.967430   19.75
# 3  21.933958   23.29
# 4  26.536777   28.24
# 5  29.875700   30.61
# 6  31.239220   30.43
# 7  31.808157   30.42
# 8  31.425070   30.93
# 9  30.913706   27.43
#
# ======================
# 🔁 Training with WINDOW SIZE: 9
# ======================
# Epoch 1/50
# 23/23 [==============================] - 8s 84ms/step - loss: 0.1491 - mae: 0.3037 - val_loss: 0.0140 - val_mae: 0.0898 - lr: 0.0010
# Epoch 2/50
#  6/23 [======>.......................] - ETA: 0s - loss: 0.0318 - mae: 0.1364
# C:\Users\HP Laptop 15\tfenv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0249 - mae: 0.1204 - val_loss: 0.0091 - val_mae: 0.0722 - lr: 0.0010
# Epoch 3/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0194 - mae: 0.1059 - val_loss: 0.0083 - val_mae: 0.0693 - lr: 0.0010
# Epoch 4/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0182 - mae: 0.1024 - val_loss: 0.0093 - val_mae: 0.0721 - lr: 0.0010
# Epoch 5/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0139 - mae: 0.0890 - val_loss: 0.0076 - val_mae: 0.0648 - lr: 0.0010
# Epoch 6/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0140 - mae: 0.0876 - val_loss: 0.0084 - val_mae: 0.0698 - lr: 0.0010
# Epoch 7/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0138 - mae: 0.0879 - val_loss: 0.0099 - val_mae: 0.0785 - lr: 0.0010
# Epoch 8/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0139 - mae: 0.0879 - val_loss: 0.0059 - val_mae: 0.0574 - lr: 0.0010
# Epoch 9/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0128 - mae: 0.0848 - val_loss: 0.0104 - val_mae: 0.0798 - lr: 0.0010
# Epoch 10/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0138 - mae: 0.0878 - val_loss: 0.0075 - val_mae: 0.0648 - lr: 0.0010
# Epoch 11/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0120 - mae: 0.0819 - val_loss: 0.0077 - val_mae: 0.0681 - lr: 0.0010
# Epoch 12/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0125 - mae: 0.0832 - val_loss: 0.0069 - val_mae: 0.0641 - lr: 0.0010
# Epoch 13/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.
50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0114 - mae: 0.0807 - val_loss: 0.0096 - val_mae: 0.0770 - lr: 0.0010
# Epoch 15/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0104 - mae: 0.0768 - val_loss: 0.0067 - val_mae: 0.0626 - lr: 0.0010
# Epoch 16/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0127 - mae: 0.0831 - val_loss: 0.0090 - val_mae: 0.0768 - lr: 0.0010
# Epoch 17/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0105 - mae: 0.0776 - val_loss: 0.0063 - val_mae: 0.0612 - lr: 2.0000e-04
# Epoch 18/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0091 - mae: 0.0701 - val_loss: 0.0072 - val_mae: 0.0661 - lr: 2.0000e-04
# Epoch 19/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0094 - mae: 0.0716 - val_loss: 0.0066 - val_mae: 0.0623 - lr: 2.0000e-04
# Epoch 20/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0100 - mae: 0.0736 - val_loss: 0.0071 - val_mae: 0.0655 - lr: 2.0000e-04
# Epoch 21/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0097 - mae: 0.0737 - val_loss: 0.0070 - val_mae: 0.0652 - lr: 2.0000e-04
# Epoch 22/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0093 - mae: 0.0716 - val_loss: 0.0069 - val_mae: 0.0647 - lr: 2.0000e-04
# Epoch 23/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0101 - mae: 0.0743 - val_loss: 0.0068 - val_mae: 0.0643 - lr: 4.0000e-05
# Epoch 24/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0097 - mae: 0.0708 - val_loss: 0.0070 - val_mae: 0.0652 - lr: 4.0000e-05
# Epoch 25/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0103 - mae: 0.0748 - val_loss: 0.0068 - val_mae: 0.0645 - lr: 4.0000e-05
# Epoch 26/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0091 - mae: 0.0706 - val_loss: 0.0068 - val_mae: 0.0642 - lr: 4.0000e-05
# Epoch 27/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0099 - mae: 0.0727 - val_loss: 0.0070 - val_mae: 0.0653 - lr: 4.0000e-05
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0041 - mae: 0.0487
# WINDOW SIZE=12
# ✅ Test Loss (MSE): 0.0041
# ✅ Test MAE:       0.0487
# 5/5 [==============================] - 1s 5ms/step
# ✅RMSE:       0.06
# ✅ MAPE:     3.13%
# ✅ R²:       0.9232
# ✅ sMAPE:    3.13%
# ✅ NSE:      0.9232
# ✅ d-index:  0.9816
#    Predicted  Actual
# 0  22.004930   21.00
# 1  19.211872   19.75
# 2  21.990427   23.29
# 3  26.734993   28.24
# 4  29.930611   30.61
# 5  31.379827   30.43
# 6  31.859243   30.42
# 7  31.260645   30.93
# 8  30.763901   27.43
# 9  29.937977   29.86

# %%
WINDOW SIZE=12
✅ Test Loss (MSE): 0.0044
✅ Test MAE:       0.0496

WINDOW SIZE=9
✅ Test Loss (MSE): 0.0046
✅ Test MAE:       0.0521

WINDOW SIZE=6
✅ Test Loss (MSE): 0.0039
✅ Test MAE:       0.0455

WINDOW SIZE=3
✅ Test Loss (MSE): 0.0064
✅ Test MAE:       0.0610

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(comparison['Actual'].values[:50], label='Actual', marker='o')
plt.plot(comparison['Predicted'].values[:50], label='Predicted', marker='x')
plt.title('Actual vs Predicted Soil Temperature (First 10 Samples)')
plt.xlabel('Sample Index')
plt.ylabel('Soil Temperature')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
